# %%
pip install spotipy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.3/250.3 kB 6.5 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import spotipy
import spotipy.oauth2 as oauth2
from spotipy.oauth2 import SpotifyOAuth
from spotipy.oauth2 import SpotifyClientCredentials
import time

# %%
df=pd.read_csv("results.csv") #gets results from csv file
related_words=["bakery"]+list(df["topic"]) +list(df["related_word"]) #adds all entries to one list
related_words=list(set(related_words)) #makes sure there no overlap

# %%
cid="45d772a85b0a4c2681a42696ad3b5ef3"
cis="9e9848f1081e459ebc686f6f62b5902d"
auth_manager=SpotifyClientCredentials(client_id=cid,client_secret=cis)
sp=spotipy.Spotify(auth_manager=auth_manager)

# %%
word_results=sp.search(q="cupcake",type=["track"])

# %%
len(word_results["tracks"]["items"])
# Out:
# 10

# %%
artist=[]
date=[]
pop=[]
uri=[]
id=[]
exp=[]
prev=[]

# %%
pd.DataFrame(columns="")

# %%
for song in word_results["tracks"]["items"]:
  row=[]
  row.append(song["artists"][0]["name"])
  row.append(song["album"]["release_date"])
  row.append(song["popularity"])
  row.append(song["uri"])
  row.append(song["id"])
  row.append(song["explicit"])
  row.append(song["preview_url"])

  # for this id call that audio features thing and get those special features

# %%
resu["tracks"]["items"][0].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
resu["tracks"]["items"][0]["artists"][0]["name"]
# Out:
# 'siouxxie sixxsta'

# %%
resu["tracks"]["items"][0]["album"]["release_date"]
# Out:
# '2020-04-22'

# %%
resu["tracks"]["items"][0]["popularity"]
# Out:
# 53

# %%
resu["tracks"]["items"][0]["uri"]
# Out:
# 'spotify:track:7oeCmvSF5mt2GqwX9YoLVk'

# %%
resu["tracks"]["items"][0]["id"]
# Out:
# '7oeCmvSF5mt2GqwX9YoLVk'

# %%
resu["tracks"]["items"][0]["explicit"]
# Out:
# True

# %%
resu["tracks"]["items"][0]["name"]
# Out:
# 'cupcakes.mp3'

# %%
resu["tracks"]["items"][0]["preview_url"]
# Out:
# 'https://p.scdn.co/mp3-preview/70259b815ee22ca4e870e199c147e9e43f99cb64?cid=45d772a85b0a4c2681a42696ad3b5ef3'

# %%
track_info=sp.audio_features("7oeCmvSF5mt2GqwX9YoLVk")

# %%
track_info
# Out:
# [{'danceability': 0.538,
#   'energy': 0.807,
#   'key': 4,
#   'loudness': -4.335,
#   'mode': 0,
#   'speechiness': 0.0912,
#   'acousticness': 0.00997,
#   'instrumentalness': 0.00721,
#   'liveness': 0.283,
#   'valence': 0.36,
#   'tempo': 164.781,
#   'type': 'audio_features',
#   'id': '7oeCmvSF5mt2GqwX9YoLVk',
#   'uri': 'spotify:track:7oeCmvSF5mt2GqwX9YoLVk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7oeCmvSF5mt2GqwX9YoLVk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7oeCmvSF5mt2GqwX9YoLVk',
#   'duration_ms': 128158,
#   'time_signature': 4}]

# %%
word_results["tracks"]["items"][0:100]["id"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-c5b280b46dac> in <cell line: 1>()
# ----> 1 word_results["tracks"]["items"][0:100]["id"]
#
# TypeError: list indices must be integers or slices, not str
