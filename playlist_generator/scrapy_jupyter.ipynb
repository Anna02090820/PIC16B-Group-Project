# %%
# !scrapy crawl related_words_spider -a ui=bakery -o results.csv
#jupyter shortcut to run command line arguments from cell
# Out:
# 2023-11-07 07:12:29 [scrapy.utils.log] INFO: Scrapy 2.8.0 started (bot: playlist_generator)
# 2023-11-07 07:12:29 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.11.5, cssselect 1.2.0, parsel 1.8.1, w3lib 1.22.0, Twisted 22.10.0, Python 3.11.6 | packaged by conda-forge | (main, Oct  3 2023, 10:29:11) [MSC v.1935 64 bit (AMD64)], pyOpenSSL 23.2.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.4, Platform Windows-10-10.0.22621-SP0
# 2023-11-07 07:12:29 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'playlist_generator',
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'playlist_generator.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['playlist_generator.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor'}
# 2023-11-07 07:12:29 [asyncio] DEBUG: Using selector: SelectSelector
# ...
